# %% [markdown]
# # How do sales trend over time?

# %% [markdown]
# ### Methodology

# %% [markdown]
# - Aggregate the sales per month per sub-category
# - Plot the monthly sales

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel('sample_superstore.xls')
df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df['order_date_month_no'] = df['Order Date'].dt.month
df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
current_month = pd.Timestamp.today().month
df_filtered = df[
    (df['Order Date'].dt.year == 2026) &
    (df['Order Date'].dt.month <= current_month)
]
df_filtered
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6815    6816  US-2026-151750 2026-01-01 2026-01-05  Standard Class
# 6816    6817  US-2026-144463 2026-01-01 2026-01-05  Standard Class
# 6817    6818  US-2026-151750 2026-01-01 2026-01-05  Standard Class
# 6818    6819  US-2026-107503 2026-01-01 2026-01-06  Standard Class
# 6819    6820  US-2026-151750 2026-01-01 2026-01-05  Standard Class
# ...      ...             ...        ...        ...             ...
# 8473    8474  US-2026-132619 2026-08-31 2026-09-05  Standard Class
# 8474    8475  US-2026-154074 2026-08-31 2026-09-02    Second Class
# 8475    8476  US-2026-127712 2026-08-31 2026-09-05  Standard Class
# 8476    8477  US-2026-117198 2026-08-31 2026-09-05  Standard Class
# 8477    8478  US-2026-107321 2026-08-31 2026-09-04  Standard Class
#
#      Customer ID      Customer Name      Segment Country/Region  \
# 6815    JM-15250       Janet Martin     Consumer  United States
# ...

# %%
df_pivot = df_filtered.pivot_table(index='order_date_month_no', columns='Sub-Category', aggfunc='size')
df_pivot.loc['Total'] = df_pivot.sum()
df_pivot = df_pivot[df_pivot.loc['Total'].sort_values(ascending=False).index]
df_pivot = df_pivot.drop('Total')
df_pivot
# Out:
# Sub-Category         Binders  Paper  Furnishings  Phones  Storage   Art  \
# order_date_month_no
# 1                       30.0   18.0         14.0    16.0     14.0  17.0
# 2                       11.0   16.0         13.0    15.0      7.0   7.0
# 3                       39.0   30.0         19.0    26.0     21.0  19.0
# 4                       36.0   24.0         28.0     9.0     15.0  22.0
# 5                       35.0   30.0         21.0    21.0     19.0  22.0
# 6                       35.0   40.0         19.0    24.0     27.0  20.0
# 7                       33.0   31.0         26.0    24.0     17.0  22.0
# 8                       37.0   29.0         20.0    17.0     25.0  16.0
#
# Sub-Category         Accessories  Chairs  Appliances  Labels  Bookcases  \
# order_date_month_no
# 1                           12.0     6.0         6.0     3.0        2.0
# 2                            6.0     5.0         9.0     2.0        5.0
# ...

# %%
df_pivot.index = df_pivot.index.map(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_pivot.index.name = 'order_date_month'
df_pivot
# Out:
# Sub-Category      Binders  Paper  Furnishings  Phones  Storage   Art  \
# order_date_month
# Jan                  30.0   18.0         14.0    16.0     14.0  17.0
# Feb                  11.0   16.0         13.0    15.0      7.0   7.0
# Mar                  39.0   30.0         19.0    26.0     21.0  19.0
# Apr                  36.0   24.0         28.0     9.0     15.0  22.0
# May                  35.0   30.0         21.0    21.0     19.0  22.0
# Jun                  35.0   40.0         19.0    24.0     27.0  20.0
# Jul                  33.0   31.0         26.0    24.0     17.0  22.0
# Aug                  37.0   29.0         20.0    17.0     25.0  16.0
#
# Sub-Category      Accessories  Chairs  Appliances  Labels  Bookcases  Tables  \
# order_date_month
# Jan                      12.0     6.0         6.0     3.0        2.0     5.0
# Feb                       6.0     5.0         9.0     2.0        5.0     3.0
# ...

# %%
df_plot = df_pivot.iloc[:,:5]

sns.lineplot(data=df_plot, dashes=False, palette='muted')
sns.despine()

plt.title('Sales Trend across Top 5 Sub-Categories')
plt.xlabel('2026')
plt.ylabel('Orders')
plt.legend().remove()

for i in range(5):
    plt.text(7.2, df_plot.iloc[-1, i], df_plot.columns[i])

plt.show()
