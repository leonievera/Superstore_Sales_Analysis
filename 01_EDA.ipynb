# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# - Amount of Orders in total
# - Amount of Products in total which were ordered
# - Amount of Customers in total who ordered
# - Countries shipped to
# - Cities with most orders
# - Different Categories
# - Different Sub-Categories with most orders

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel('sample_superstore.xls')
df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
orders_total = df['Order ID'].value_counts().count()
orders_total
# Out:
# np.int64(5111)

# %%
products_total = df['Product ID'].value_counts().count()
products_total
# Out:
# np.int64(1862)

# %%
customers_total = df['Customer ID'].value_counts().count()
customers_total
# Out:
# np.int64(804)

# %%
countries_total = df['Country/Region'].value_counts()
countries_total
# Out:
# Country/Region
# United States    9994
# Canada            200
# Name: count, dtype: int64

# %%
wedges, texts, autotexts = plt.pie(
    countries_total,
    labels=['United States', 'Canada'],
    autopct='%1.1f%%',
    startangle=90,
    pctdistance=0.8,
)

for autotext in autotexts:
    autotext.set_color('white')

plt.title('Distribution of the Countries')
plt.figure(facecolor='white')
plt.show()

# %%
cities_total = df['City'].value_counts()
cities_total = cities_total.to_frame()
cities_orders = cities_total.head(10)
cities_orders
# Out:
#                count
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163

# %%
sns.barplot(data=cities_orders, x='count', y='City')
sns.despine()
sns.set_style('white')
plt.title('Amount of Orders for Top 10 Cities')
plt.xlabel('Orders')
plt.ylabel('')
plt.show()

# %%
categories_total = df['Category'].value_counts()
categories_total
# Out:
# Category
# Office Supplies    6128
# Furniture          2201
# Technology         1865
# Name: count, dtype: int64

# %%
sub_categories_total = df['Sub-Category'].value_counts()
sub_categories_total = sub_categories_total.to_frame()
sub_categories_orders = sub_categories_total.head(10)
sub_categories_orders
# Out:
#               count
# Sub-Category
# Binders        1548
# Paper          1384
# Furnishings    1009
# Phones          903
# Storage         856
# Art             821
# Accessories     775
# Chairs          634
# Appliances      474
# Labels          368

# %%
sns.barplot(data=sub_categories_orders, x='count', y='Sub-Category')
sns.despine()
sns.set_style('white')
plt.title('Amount of Orders for Top 10 Sub-Categories')
plt.xlabel('Orders')
plt.ylabel('')
plt.show()
